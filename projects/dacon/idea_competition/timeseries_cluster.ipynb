# %% [markdown]
# ### Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import plotly
from tqdm import tqdm

from sklearn.cluster import KMeans
from sklearn.preprocessing import Normalizer

# %%
with open('./data/cluster_data/stockcodes.json', 'r', encoding='utf-8') as f:
    codes = json.load(f)

df = pd.read_csv('./data/cluster_data/stockcandles_day.csv', dtype={'code':str})

# %%
def load_data():
    with open('./data/cluster_data/stockcodes.json', 'r', encoding='utf-8') as f:
        codes = json.load(f)

    df = pd.read_csv('./data/cluster_data/stockcandles_day.csv', dtype={'code':str})

    return codes, df

# %%
codes, df = load_data()

# %%
len(codes)
# Out:
# 2375

# %%
df
# Out:
#           code      date    close     high      low     open   volume
# 0       082740  20220531   8730.0   8840.0   8520.0   8520.0   387301
# 1       082740  20220530   8510.0   8640.0   8380.0   8630.0   373313
# 2       082740  20220527   8450.0   8510.0   8240.0   8410.0   446609
# 3       082740  20220526   8390.0   8560.0   8220.0   8290.0   489793
# 4       082740  20220525   8260.0   8310.0   7990.0   8090.0   609532
# ...        ...       ...      ...      ...      ...      ...      ...
# 322475  389030  20211115  12650.0  12950.0  12350.0  12600.0   272215
# 322476  389030  20211112  12650.0  13500.0  12250.0  12350.0   554986
# 322477  389030  20211111  12350.0  12900.0  12100.0  12100.0   450149
# 322478  389030  20211110  12150.0  12750.0  12100.0  12700.0   441404
# 322479  389030  20211109  12800.0  13700.0  12250.0  13350.0  1156403
#
# [322480 rows x 7 columns]

# %%
df[df['code'] == '389030']
# Out:
#           code      date    close     high      low     open   volume
# 322341  389030  20220531  10900.0  11100.0  10800.0  10950.0    22787
# 322342  389030  20220530  11000.0  11150.0  10800.0  10950.0    43236
# 322343  389030  20220527  10850.0  11150.0  10750.0  10800.0    37268
# 322344  389030  20220526  10550.0  11000.0  10150.0  10150.0   104899
# 322345  389030  20220525  10150.0  10250.0   9950.0  10100.0     9856
# ...        ...       ...      ...      ...      ...      ...      ...
# 322475  389030  20211115  12650.0  12950.0  12350.0  12600.0   272215
# 322476  389030  20211112  12650.0  13500.0  12250.0  12350.0   554986
# 322477  389030  20211111  12350.0  12900.0  12100.0  12100.0   450149
# 322478  389030  20211110  12150.0  12750.0  12100.0  12700.0   441404
# 322479  389030  20211109  12800.0  13700.0  12250.0  13350.0  1156403
#
# [139 rows x 7 columns]

# %%
X = []
names = []
w = 20
n = 120+w-1

for code_item in tqdm(codes):
    code = code_item['code']
    # print(f'code: {code}')
    _df = df[df['code'] == code].dropna()
    # print(f'len _df: {len(_df)}')

    if len(_df) < n:
        continue

    _df = _df.sort_values(by='date', ascending=True)
    _df['x'] = _df['close'] / _df.iloc[0]['close'] - 1
    _df = _df.dropna()
    # print(len(_df))

    if len(_df) < n:
        continue

    _df['x'] = pd.Series(_df['x']).rolling(w).mean()
    X.append(_df['x'].tolist()[w-1:])
    names.append(code_item['name'])

X = np.array(X)
names = np.array(names)
# Out:
# 100%|██████████| 2375/2375 [01:05<00:00, 36.19it/s]

# %%
len(X)
# Out:
# 2320

# %%
k = 30
model = KMeans(n_clusters=k, random_state=42)
model.fit(Normalizer().fit_transform(X))

from collections import Counter
print(Counter(model.labels_))
# Out:
# Counter({23: 309, 12: 194, 25: 193, 5: 134, 22: 124, 1: 114, 18: 112, 0: 100, 24: 81, 4: 79, 10: 77, 2: 72, 21: 69, 29: 67, 3: 60, 16: 54, 28: 54, 7: 50, 8: 44, 14: 42, 6: 41, 11: 40, 20: 37, 17: 35, 26: 30, 13: 29, 27: 21, 19: 21, 15: 19, 9: 18})

# %%
names
# Out:
# array(['HSD엔진', 'KG케미칼', 'LG이노텍', ..., '피코그램', '카카오페이', '지니너스'],
#       dtype='<U14')

# %%
import matplotlib.font_manager as fm
import matplotlib
from scipy.spatial.distance import euclidean

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = 'Malgun Gothic'
fm.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font_name)
matplotlib.rc('axes', unicode_minus=False)

def plot_clusters(model, k):
    # %matplotlib inline
    c = 5
    fig, axes = plt.subplots(nrows=k, ncols=c+1, figsize=(c*3, k*2))

    for label in range(k):
        x = model.cluster_centers_[label]
        axes[label][0].plot(np.arange(len(x)), x)
        axes[label][0].set_title(f'Cluster_{label}: Trend')
        axes[label][0].set_ylim([min(x.min()-0.01, 0.1), max(x.max()+0.01, 0.1)])
        n = 0
        _X = X[model.labels_ == label]
        _names = names[model.labels_ == label]
        dist = [euclidean(x, _x) for _x in _X]
        idxs = np.argsort(dist)[:c]

        for x, name in zip(_X[idxs], _names[idxs]):
            n += 1
            axes[label][n].plot(np.arange(len(x)), x)
            axes[label][n].set_title(f'{label}: {name}')
            axes[label][n].set_ylim([min(x.min()-0.01, 0.1), max(x.max()+0.01, 0.1)])
            if n >= c:
                break

    plt.tight_layout()
    plt.show()

plot_clusters(model, k)
# Out:
# ['SH에너지화학' '경동도시가스' '이리츠코크렙' '한일철강' 'GS글로벌' '사조대림' '사조동아원' '태경케미컬' '동아지질'
#  '베트남개발1' '이월드' '하이스틸' '한신기계공업' 'AJ네트웍스' '무림P&P' '신송홀딩스' '영원무역홀딩스' '샘표'
#  '일동홀딩스' '크라운해태홀딩스' 'KG스틸' '부국철강' '삼천리' '세아제강지주' '전방' '팜스코' '해성디에스' '화천기계'
#  '고려산업' '대창단조' '도화엔지니어링' 'TYM' '에스제이엠홀딩스' '태경산업' '세아제강' '에스티오' '한국맥널티'
#  '한국전자금융' 'KBI메탈' '베셀' '삼양옵틱스' '케이씨피드' '하림' '대한뉴팜' '테라사이언스' '아비코전자'
#  '케이피에프' '피앤씨테크' '현대사료' '휴림로봇' '일야' '한일사료' '베뉴지' '대동기어' '쌍용정보통신' '에프앤리퍼블릭'
#  '이스트아시아홀딩스' '기산텔레콤' '동우팜투테이블' '메이슨캐피탈' '무림SP' '쎄니트' '그리티' '티엘아이' '홈센타홀딩스'
#  '금강철강' '아이에스이커머스' '케어젠' '한탑' '대동스틸' '신영스팩5호' '대모' '교보9호스팩' '하나금융14호스팩'
#  '노터스' '태웅로직스' '대신밸런스제8호스팩' '하나금융15호스팩' '신영스팩6호' 'SK6호스팩' 'IBKS제13호스팩'
#  '하나금융16호스팩' '에이치엠씨제4호스팩' '미래에셋대우스팩 5호' '교보10호기업인수목적' 'DB금융스팩8호'
#  '에이치엠씨제5호스팩' '유안타제7호스팩' '파이버프로' '신한제7호스팩' '하나금융17호스팩' '하인크코리아' '유안타제8호스팩'
#  '유진스팩6호' 'IBKS제16호스팩' '현대중공업' '대신밸런스제10호스팩' '신한제8호스팩' '엔에이치스팩20호'
#  '하나금융19호스팩']
# ['SK네트웍스' '대웅' '롯데하이마트' '미래에셋생명' '삼성출판사' '한국조선해양' 'SKC' '동양생명' '세방전지'
#  '종근당' '한독' '한일현대시멘트' 'YG PLUS' '비비안' '유진증권' '유화증권' '종근당바이오' '텔코웨어'
#  '한국자산신탁' '삼성물산' '세기상사' '셀트리온' '씨에스윈드' '평화홀딩스' '포스코스틸리온' '한화' 'DB금융투자'
#  'KPX홀딩스' '디아이동일' '부광약품' '신세계I&C' '카카오' '국도화학' '세아베스틸지주' '인바이오젠' '한올바이오파마'
#  '효성첨단소재' '다우기술' '동화약품' '일양약품' '한국쉘석유' '한익스프레스' 'KTcs' '노루홀딩스' '대신증권'
#  '동아에스티' '인스코비' '일성건설' '효성' '나스미디어' '디오' '알테오젠' '위지트' '휴메딕스' '옵티시스'
#  '에이비프로바이오' '정상제이엘에스' '포스코케미칼' 'SBS콘텐츠허브' '초록뱀컴퍼니' '디지털대성' '메디톡스' '쎌바이오텍'
#  '아이오케이' '포스코 ICT' '한국경제TV' '신원종합개발' '지니뮤직' '초록뱀미디어' '코엔텍' '경동제약' '아즈텍WB'
#  '앤디포스' '예스24' '이엠코리아' '파이오링크' '펩트론' '하이텍팜' '한국큐빅' '선익시스템' '위지윅스튜디오'
#  'iMBC' '대정화금' '동양이엔피' '디알젬' '에스트래픽' '이크레더블' '멜파스' '신일제약' '유비케어' '제룡산업'
#  '차바이오텍' '코콤' '아이스크림에듀' '솔루스첨단소재' '씨에스베어링' '라파스' '녹십자웰빙' '에스케이바이오팜' '미투젠'
#  '비비씨' '비나텍' '씨엔알리서치' '미코바이오메드' '위드텍' '하이딥' '석경에이티' '프레스티지바이오파마' '에이치피오'
#  '맥스트' '애드바이오텍' '래몽래인' '리파인' '지니너스']
# ['한솔테크닉스' '아세아제지' '한국전자홀딩스' 'KEC' '삼성전기' '씨아이테크' '지투알' '한미반도체' '효성화학'
#  '삼아알미늄' '락앤락' '한일시멘트' 'GH신소재' 'GST' '컴투스홀딩스' '미래컴퍼니' '제주반도체' '파수' '비트컴퓨터'
#  '삼진' '이노와이어리스' '크리스에프앤씨' '두산테스나' 'PI첨단소재' '램테크놀러지' '유진테크' '마이더스AI'
#  '애니플러스' '엘오티베큠' '케이엔더블유' '고영' '다날' '액트로' '전진바이오팜' '케어랩스' '홈캐스트' '비투엔'
#  '대림제지' '시티랩스' '아이원스' '에스티팜' '원익IPS' '젬백스링크' '한글과컴퓨터' '앤씨앤' '와이아이케이' '월덱스'
#  '네오리진' '파트론' 'FSN' '디와이피엔에프' '동운아나텍' '리노공업' '옴니시스템' '와이제이엠게임즈' '세경하이테크'
#  '덕산테코피아' '라닉스' '케이엔제이' '아톤' 'RF머트리얼즈' '피피아이' '위세아이텍' '제놀루션' '바이브컴퍼니'
#  '엔비티' '핑거' '제노코' '이삭엔지니어링' '엠로' '케이카' '엔켐']
# ['KSS해운' '세원정공' '와이투솔루션' '쌍용자동차' '센트럴인사이트' '에스엠벡셀' '컨버즈' '쎌마테라퓨틱스' '이엠앤아이'
#  'UCI' '매직마이크로' '명성티엔에스' '스카이문스테크놀로지' '에스디시스템' '이큐셀' '휴엠앤씨' '에이치엔티' '유네코'
#  '연이비앤티' '좋은사람들' '코스온' 'CNT85' '뉴로스' '애머릿지' '파나케이아' 'BNGT' '디모아' '디에스앤엘'
#  '바른전자' '신라젠' '코원플레이' '제이웨이' '나노캠텍' '세원물산' '큐리언트' '녹원씨엔아이' '아이톡시' '참존글로벌'
#  '태웅' '레드로버' '에스앤더블류' 'ITX-AI' '대양제지' '디아크' '어스앤에어로스페이스' '협진' '엑세스바이오'
#  '엔지스테크널러지' '우리로' '유테크' '코오롱티슈진' '한국정밀기계' '비츠로시스' '소리바다' '아리온' '커머스마이너'
#  '하이소닉' '디엑스앤브이엑스' '코센' '테라셈']
# ['HSD엔진' '삼일씨엔에스' '제일연마' '현대비앤지스틸' 'JW중외제약' '금강공업' '대림통상' '대우건설' '신영와코루'
#  'HMM' '현대해상' '콤텍시스템' 'JW홀딩스' 'LS네트웍스' 'NI스틸' 'SPC삼립' '대성에너지' '대한제분'
#  '디와이파워' '에이엔피' '페이퍼코리아' 'CJ씨푸드' '문배철강' '바다로19호' '웰바이오텍' '팬오션' '동원수산'
#  '삼성엔지니어링' '이구산업' '황금에스티' 'LX인터내셔널' 'SIMPAC' '방림' 'STX엔진' '롯데칠성음료' '이화산업'
#  '일성신약' '한성기업' '현대미포조선' 'CJ프레시웨이' 'TJ미디어' '대봉엘에스' '삼목에스폼' '에이티세미콘'
#  '내츄럴엔도텍' '삼일기업공사' '삼화네트웍스' '스페코' '코위버' '서부T&D' '시공테크' '한일네트웍스' '경남스틸'
#  '대창스틸' '도이치모터스' '아우딘퓨쳐스' '에쎈테크' '엘컴텍' '제노레이' '티플랙스' 'SG&G' '엔에스엔' '한국선재'
#  '인터로조' '케이씨티' '넥슨게임즈' '미래생명자원' '중앙에너비스' '케이프' 'YTN' '보성파워텍' '상상인'
#  '알에스오토메이션' '에스씨디' '누보' '에스제이그룹' '제주맥주' '바이오플러스' '아이패밀리에스씨']
# ['LG이노텍' '코리아써키트' '영진약품' 'SK텔레콤' '진양폴리우레탄' 'DB하이텍' '경인전자' '우진플라임' '참엔지니어링'
#  '엔피씨' '유유제약' '진양홀딩스' '한국특강' 'SG세계물산' 'SK하이닉스' '농심' '유니퀘스트' '성신양회' '율촌화학'
#  '티에이치엔' 'YW' '네오티스' '디케이티' '에스티아이' '에이피티씨' '오스템임플란트' '오픈베이스' '웨이브일렉트로'
#  '육일씨엔에쓰' '주성엔지니어링' '코이즈' '한양디지텍' '디알텍' '러셀' '로체시스템즈' '메디아나' '모트렉스' '브이원텍'
#  '블루콤' '영신금속' '영화테크' '원일특강' '인포뱅크' '타이거일렉' '티에스이' '한솔인티큐브' 'NHN벅스' '기가레인'
#  '탑코미디어' '로보스타' '모바일어플라이언스' '브리지텍' '성우테크론' '셀바스AI' '아진엑스텍' '유티아이' '티로보틱스'
#  '동진쎄미켐' '라이트론' '메카로' '싸이맥스' '에스넷' '유비벨록스' '이녹스첨단소재' '피씨디렉트' '피에스케이홀딩스'
#  '픽셀플러스' '한국컴퓨터' '노바텍' '스맥' 'SGC이테크건설' '인텔리안테크' '칩스앤미디어' '엑스큐어' 'JW신약'
#  'SG' '미래나노텍' '위메이드플레이' '세코닉스' 'LX세미콘' '에스에이티' '엠플러스' '제닉' '제이엠아이' '지니언스'
#  'ISC' '나무가' '로보티즈' '멀티캠퍼스' '빅솔론' '성우전자' '아바코' '영우디에스피' '인베니아' '제이엠티'
#  '케이엠' '켐트로닉스' '코오롱생명과학' '파인디앤씨' '현대바이오' '휴마시스' '덕산하이메탈' '마이크로컨텍솔' '아이씨케이'
#  '에치에프알' '엠벤처투자' '오션브릿지' '유니트론텍' '텔레칩스' '하이비젼시스템' '이지케어텍' '드림텍' '피에스케이'
#  '수젠텍' '프로이천' '플리토' '네오크레마' '팜스빌' '신테카바이오' '하이제5호스팩' '드림씨아이에스' '블리츠웨이'
#  '레인보우로보틱스' '피엔에이치테크' '싸이버원' '해성티피씨' 'LX홀딩스' '에이디엠코리아' '에스디바이오센서' '바이옵트로'
#  '씨유테크' '엔에이치스팩21호' '지앤비에스엔지니어링' '피코그램']
# ['LG디스플레이' '디아이' '삼성전자' 'LG전자' '삼양패키징' '비케이탑스' 'HLB글로벌' '삼화전자공업' '신한알파리츠'
#  '삼보판지' '세종메디칼' '알에프세미' '엘아이에스' '한국전자인증' 'KPX생명과학' '서울제약' '자이글' '네오위즈홀딩스'
#  '마이크로프랜드' '메지온' '유니셈' '탑엔지니어링' '엠씨넥스' 'KH바텍' '한국정보공학' '에이테크솔루션' '에코캡'
#  '한국비엔씨' '오스코텍' '이라이콤' '조이시티' '해성산업' '코아시아' '윌링스' '나노브릭' '핌스' '클리노믹스'
#  '아이퀘스트' '바이오다인' '오비고' '인카금융서비스']
# ['극동유화' '롯데손해보험' '우진' '한국철강' '대현' '하이트진로' '한국콜마' '한국공항' '강원랜드' '대창' '대한해운'
#  'BGF리테일' 'KISCO홀딩스' '경농' '대원전선' '한세실업' '광주신세계' '일신방직' '제주항공' '하나투어'
#  '흥국화재' '레드캡투어' '한일화학' '서전기전' '오르비텍' '참좋은여행' '패션플랫폼' '피제이메탈' '노블엠앤비' '아스트'
#  '코스메카코리아' '대한그린파워' '풍국주정' '큐로홀딩스' '파마리서치' '대호특수강' '인바디' '한창산업' '매일홀딩스'
#  '세화피앤씨' '우리기술' '인산가' '코디' '농우바이오' '에너토크' '코리아나' '엔바이오니아' '더네이쳐홀딩스' '앱코'
#  '씨앤씨인터내셔널']
# ['유나이티드' '키다리스튜디오' '경보제약' 'DL건설' '일정실업' '신영증권' '메타랩스' '삼익악기' '초록뱀헬스케어'
#  '한국ANKOR유전' '플레이그램' '성안' '롯데정보통신' '삼기' '썸에이지' '에이티넘인베스트' '크로바하이텍' '트루윈'
#  'SBI핀테크솔루션즈' '티에스넥스젠' '메디앙스' '서울반도체' '스킨앤스킨' 'DSC인베스트먼트' '에스아이리소스'
#  '글로벌에스엠' '강원에너지' '재영솔루텍' '힘스' '골드앤에스' '상상인인더스트리' '감성코퍼레이션' '진로발효' '한송네오텍'
#  '블루베리 NFT' '씨엔플러스' '엔시트론' '예스티' '크린앤사이언스' '에이에프더블류' '미래에셋대우스팩3호' '자이에스앤디'
#  '솔트룩스' '지아이텍']
# ['다스코' '코스모신소재' '부산주공' '대성산업' '혜인' 'KTis' '대한제당' '한국종합기술' '현대에버다임' '태양'
#  '구영테크' '서암기계공업' '신화콘텍' '태광' 'THQ' '텔레필드' '켄코아에어로스페이스' '티엘비']
# ['고려제강' '아시아나항공' '제이에스코퍼레이션' '호텔신라' 'GKL' 'SG글로벌' '빙그레' '아모레퍼시픽그룹' '영풍'
#  '진에어' '한국가스공사' 'CJ CGV' '삼성중공업' '삼화페인트공업' '유니켐' '태평양물산' 'SK렌터카' '금비'
#  '기신정기' '알루코' '에이블씨엔씨' '조비' '한국화장품제조' '케이탑리츠' 'JW생명과학' '대한항공' '동양고속'
#  'SUN&L' 'AK홀딩스' '신세계인터내셔날' '하이트진로홀딩스' '한국콜마홀딩스' '한신공영' '현대백화점' '흥아해운'
#  '그린케미칼' '한국전력공사' '티웨이항공' '아시아나IDT' '에어부산' '디지틀조선' '이상네트웍스' '제이엔케이히터'
#  'HRS' 'SGA솔루션즈' '모두투어' '에스엠' '콜마비앤에이치' 'KCC건설' 'SM C&C' '바텍' '에이스침대'
#  '이원컴포텍' '파라다이스' '글로벌텍스프리' '알톤스포츠' '케이아이엔엑스' '코텍' '본느' '그래디언트' '잉글우드랩'
#  '에프엔씨엔터' '오로라' '클리오' 'NICE평가정보' '네오팜' '대륙제관' '와이지엔터테인먼트' '제너셈' '네오오토'
#  '와토스코리아' '자연과환경' '한국기업평가' '컴퍼니케이' '펌텍코리아' '피엔케이피부임상연구센타' '디앤디플랫폼리츠']
# ['환인제약' '국제약품' '진흥기업' '남선알미늄' '미창석유공업' '대우조선해양' '세아특수강' '한화손해보험' '잇츠한불'
#  '한솔피엔에스' '이브이첨단소재' '에코마케팅' 'PN풍년' '광림' '대유에이피' '삼지전자' '연우' '보광산업' '바이넥스'
#  '비에이치아이' '우리이앤엘' '효성오앤비' '엠피대산' '남화토건' '비엠티' '서울리거' '우리엔터프라이즈' '이화공영'
#  'JYP Ent.' '고려시멘트' '고려제약' '바이오톡스텍' '일진파워' '화일약품' '줌인터넷' '롯데리츠' 'NH프라임리츠'
#  '엔에프씨' 'ESR켄달스퀘어리츠' '롯데렌탈']
# ['세원이앤씨' '인지컨트롤스' '제일약품' '현대건설기계' '진원생명과학' '하이트론씨스템즈' '현대퓨처넷' '효성티앤씨'
#  'HDC현대산업개발' '엔에이치엔' '금양' '덕성' '스틱인베스트먼트' '삼성에스디에스' '삼성증권' '코오롱' 'NH투자증권'
#  'SK증권' '삼성제약' '서연' 'DGB금융지주' 'HDC현대EP' 'SK디스커버리' 'SK이노베이션' '더존비즈온' '동부건설'
#  '삼성공조' '삼양홀딩스' '신원' '이아이디' '한화솔루션' '형지엘리트' 'LG화학' '교보증권' '다이나믹디자인' '에스엘'
#  '한국단자공업' '오리엔트바이오' '오리온홀딩스' '팜젠사이언스' '조광페인트' '한양증권' '현대위아' '현대자동차'
#  '현대차증권' '금호전기' '미래에셋증권' '미원상사' '유엔젤' '한창' '현대로템' '현대모비스' '현대약품' '골드퍼시픽'
#  '원바이오젠' '덕산네오룩스' '바이오솔루션' '셀트리온헬스케어' '아이씨디' '에스코넥' '에프에스티' '오이솔루션'
#  '이스트소프트' '이트론' '진매트릭스' '케이피엠테크' '토탈소프트' 'CS' '대아티아이' '미코' '미투온' '성우하이텍'
#  'HLB제약' '안트로젠' '에스에스알' '에스와이' '에이스테크' '엔지켐생명과학' '오리엔트정공' '유니테스트'
#  '유바이오로직스' '유틸렉스' '캐스텍코리아' '투비소프트' '피에스텍' '한국정보통신' '형지I&C' '휴온스글로벌' '경창산업'
#  '비피도' '셀루메드' '셀리버리' '신성델타테크' '에이디칩스' '에이치시티' '에프엔에스테크' '웹젠' '위닉스' '필옵틱스'
#  '나이벡' '옵트론텍' '제넨바이오' '제노포커스' '젬백스' '코맥스' '코세스' '한국코퍼레이션' '국일제지' '디앤씨미디어'
#  '세종텔레콤' '알엔투테크놀로지' '에스앤에스텍' '에스티큐브' '에이텍티앤' '엠케이전자' '오스테오닉' '위메이드' '유아이엘'
#  'KH 건설' '이퓨쳐' '제넥신' '파라텍' '프리엠스' '디에이테크놀로지' 'KH 전자' '서연탑메탈' '세진티에스'
#  '에이트원' '아이진' '지더블유바이텍' '이화전기' '지엘팜텍' '컴투스' '케이엠더블유' '케이피에스' '크루셜텍'
#  '크리스탈지노믹스' '테라젠이텍스' 'NE능률' 'SBW생명과학' '대성엘텍' '엠투엔' '바이오로그디바이스' '아이큐어'
#  '애니젠' '액토즈소프트' '에이텍' '엔텔스' '이엘피' '인콘' '에이루트' '카페24' 'S&K폴리텍' '네오펙트'
#  '스카이이앤엠' '시스웍' '올릭스' '이즈미디어' '메디콕스' 'HLB테라퓨틱스' '케이엠제약' '텔콘RF제약' '엠에프엠코리아'
#  '세틀뱅크' '레이' 'HDC' '지누스' '라온피플' '티움바이오' '메드팩토' '서남' '레몬' '서울바이오시스'
#  '에스씨엠생명과학' '에스에이티이엔지' 'HB솔루션' '젠큐릭스' '셀레믹스' '압타머사이언스' '원방테크' '네패스아크'
#  '명신산업' '퀀타매트릭스' '인바이오' '알체라' '프리시젼바이오' '지놈앤컴퍼니' '와이더플래닛' '뷰노' '나노씨엠에스'
#  'F&F' '이노뎁' 'HK이노엔' '크래프톤']
# ['노루페인트' '대구백화점' 'SK디앤디' '한진칼' '태원물산' '금호건설' '에스제이엠' '마크로젠' '헬릭스미스'
#  '엘비세미콘' '프로스테믹스' '서진시스템' '앱클론' '링네트' '머큐리' '다우데이타' '야스' '에스엠코어'
#  '인피니트헬스케어' '일신바이오' '켐온' '바른손이앤에이' '파인텍' '백금T&A' '파워로직스' '휴맥스'
#  'CJ 바이오사이언스' '신도기연' '티앤엘']
# ['디씨엠' '영보화학' '유한양행' '이수화학' '맥쿼리인프라' 'CJ제일제당' '수산중공업' '한일홀딩스' 'JB금융지주'
#  '아남전자' '포스코인터내셔널' 'KB오토시스' '뉴프렉스' '디엔에프' '원익QnC' '이엔에프테크놀로지' '빛샘전자' 'KCI'
#  '나노신소재' '디엔에이링크' '티씨케이' '지니틱스' '알에프텍' '이루온' '강스템바이오텍' '성도이엔지' '엔브이에이치코리아'
#  '엔피케이' '하나머티리얼즈' '한양이엔지' '에스엔유' '윈스' '코아시아옵틱스' '플레이위드' '네온테크' '세동'
#  '이오테크닉스' '테스' '테크윙' '현대오토에버' '와이엠텍' '유진스팩7호']
# ['까뮤이앤씨' '써니전자' '영원무역' '디티알오토모티브' '디아이씨' '강남제비스코' '광진실업' '캠시스' '티피씨글로벌'
#  '로지시스' '성호전자' '뷰웍스' '알리코제약' '신라섬유' '피제이전자' '코윈테크' '포커스에이치엔에스' '티에스아이'
#  '샘씨엔에스']
# ['대영포장' '동아쏘시오홀딩스' '삼성바이오로직스' '삼진제약' '한국토지신탁' '미원홀딩스' '신라교역' '태림포장' '케이씨텍'
#  '웰크론' '알로이스' '스타플렉스' '한국팩키지' '솔본' '인성정보' '파크시스템스' '서원인텍' '씨젠' '한컴위드' '광무'
#  '비덴트' '지어소프트' '팅크웨어' '휴네시온' 'RFHIC' '레고켐바이오' '룽투코리아' 'EV수성' '드림어스컴퍼니'
#  '케이디켐' '드래곤플라이' '엔피' '에스디생명공학' '현대이지웰' '인트로메딕' '인트론바이오' 'AP시스템' 'KG모빌리언스'
#  'SFA반도체' '키네마스터' '누리플렉스' '멕아이씨에스' '티사이언티픽' '소프트캠프' '브릿지바이오' '솔브레인'
#  '영림원소프트랩' '모비릭스' '씨앤투스성진' '오로스테크놀로지' '라이프시맨틱스' '플래티어' '브레인즈컴퍼니' '카카오페이']
# ['SK' '쌍방울' '파미셀' '한국수출포장공업' '대덕' '백광산업' '현대제철' '서울식품공업' '엘브이엠씨' '신도리코'
#  '유수홀딩스' '하나제약' '삼아제약' '알티캐스트' '에이팩트' '한컴MDS' '해성옵틱스' '에프알텍' '현대공업'
#  'KG ETS' '엘디티' '골프존' '골프존뉴딘홀딩스' '시너지이노베이션' '아나패스' '오킨스전자' '와이엠티' '삼강엠앤티'
#  '아이컴포넌트' '한국정보인증' '우리바이오' '동화기업' '와이어블' '마니커에프앤지' '진시스템']
# ['WISCOM' '삼성카드' '삼영전자공업' '제이준코스메틱' '케이씨' '코오롱플라스틱' '한진' '한창제지' 'SNT모티브'
#  '대한전선' '동원금속' '미원에스씨' '보락' '아이마켓코리아' '큐로' '토니모리' '화천기공' 'LG헬로비전' 'SBS'
#  '기아' '삼정펄프' '성보화학' '예스코홀딩스' '한솔홀딩스' 'LS' '맵스리얼티1' '세우글로벌' 'SNT홀딩스' '모나리자'
#  '부국증권' '삼성생명' '케이티스카이라이프' '현대일렉트릭' '화신' 'LG유플러스' '남해화학' '동양철관' '동일고무벨트'
#  '부산산업' '오뚜기' '인터지스' '일진홀딩스' '지엠비코리아' '한국화장품' '롯데제과' '세방' '한농화성'
#  '현대코퍼레이션홀딩스' '상신브레이크' '유성기업' '천일고속' '체시스' '현대코퍼레이션' 'HD현대' '우진아이엔에스'
#  '리더스코스메틱' '싸이토젠' '오공' '지엔코' '창해에탄올' '지엔원에너지' '나우IB' '매일유업' '비아트론' '상신이디피'
#  '아모텍' '아미코젠' '예림당' '제이스코홀딩스' '풍강' '다산네트웍스' '듀오백' '부방' '원익홀딩스' '진바이오텍'
#  '한국캐피탈' '대성미생물' '덕신하우징' '동국제약' '사람인에이치알' '에코플라스틱' '엑사이엔씨' '엔에스'
#  '포인트엔지니어링' '케이에스피' '뉴보텍' '신흥에스이씨' '아이센스' '양지사' '어보브반도체' '에코바이오' '화신정공'
#  '리노스' '엔케이맥스' '흥국' '동성화인텍' '디스플레이텍' '아미노로직스' '아스타' '유신' '진성티이씨' '한국가구'
#  '상지카일룸' '쏠리드' '아이앤씨' '에스폴리텍' '이미지스' '코렌텍' '에코프로비엠' '지노믹트리' '휴럼' '원준']
# ['신성통상' '세진중공업' 'NICE' '녹십자엠에스' 'SV인베스트먼트' 'ES큐브' '와이엔텍' '딜리' '세중' '동국S&C'
#  '모다이노칩' '흥구석유' 'EDGC' '한라IMS' '희림' '현대무벡스' '코리아에셋투자증권' '엠브레인' '소룩스'
#  '포인트모바일' '선진뷰티사이언스']
# ['태광산업' '케이씨씨' '삼화콘덴서공업' 'BYC' '메리츠금융지주' '뉴인텍' '톱텍' '덕우전자' '레이크머티리얼즈'
#  '모아텍' '아이에이' '엘티씨' '유에스티' '팬젠' '휴맥스홀딩스' '로스웰' '이노메트리' '나인테크' '나라엠앤디'
#  'DMS' 'KMH하이텍' '모베이스' '바이오스마트' '비엘' '우주일렉트로' '엑시콘' '바른손' '인텍플러스' '큐에스아이'
#  '제이엘케이' '위더스제약' '에이프로' '엠투아이' '유일에너테크' '엔시스' '엘비루셈' '아모센스']
# ['무학' '삼영화학공업' '아이에스동서' '한국패러랠' 'CS홀딩스' 'KB금융' '대한방직' '대한제강' '진양화학'
#  '한국석유공업' '대동전자' '삼일제약' '삼화왕관' '이엔플러스' '코리안리' '메리츠화재' 'SGC에너지' '아세아시멘트'
#  '퍼스텍' '디와이' '새론오토모티브' '신세계' '진양산업' '화인베스틸' '동일산업' '서울도시가스' '신대양제지' '신흥'
#  '제주은행' '하나금융지주' '위니아' '와이지-원' '국순당' '이엠텍' '코다코' '파인디지털' '대성파인텍' '삼천리자전거'
#  '플래스크' '토비스' '프로텍' '이랜시스' '노바렉스' '옵티팜' '피에이치씨' '현우산업' '대신정보통신' '로보로보'
#  '안국약품' '오디텍' '에디슨INNO' '인터플렉스' '큐렉소' '포시에스' '한일단조' '한일진공' '동양에스텍'
#  '디에이치피코리아' '대보마그네틱' '에이비엘바이오' '한네트' '미래에셋벤처투자' 'TS트릴리온' '윈텍' '현대에너지솔루션'
#  '우양' '티라유텍' '하나기술' '에브리봇']
# ['대원제약' '모두투어리츠' '신한지주' '원림' '일동제약' '조일알미늄' '백산' '사조씨푸드' '삼양식품' '송원산업'
#  '조선선재' '케이티' '한국항공우주' '경방' '대웅제약' '메리츠증권' 'SHD' '풍산홀딩스' '한화에어로스페이스'
#  '휴니드테크놀러지스' 'LIG넥스원' '사조오양' '삼익THK' '아세아' 'TCC스틸' '만호제강' '한미글로벌' 'DB손해보험'
#  '고려아연' '자화전자' '화성산업' '휴스틸' '대동' '덴티움' '동원시스템즈' '이수페타시스' '현대글로비스' '대성홀딩스'
#  '사조산업' '삼부토건' '신일전자' '영풍제지' '테이팩스' '우리금융지주' '동방선기' '디에이피' '세보엠이씨' '제우스'
#  '파세코' '데이타솔루션' '심텍홀딩스' '엠아이텍' '제이스텍' '피델릭스' '핸디소프트' 'AP위성' '디와이디' '디지아이'
#  '모바일리더' '삼현철강' '서플러스글로벌' '소프트센' '아이엠' '에스에프에이' '원익머트리얼즈' '이랜텍' '인탑스'
#  '포메탈' '파커스' '메가스터디교육' '큐캐피탈' 'TPC' '네이블커뮤니케이션즈' '디티앤씨' '셀바스헬스케어' '시그네틱스'
#  '에스피지' 'CSA 코스믹' '네오셈' '디이엔티' '비에이치' '빅텍' '아이쓰리시스템' '우림피티에스' '선광' '시큐브'
#  '심텍' '씨유메디칼' '씨티씨바이오' '와이오엠' '우리넷' '유진로봇' '지에스이' '하림지주' '현대에이치티' '흥국에프엔비'
#  '동일금속' '루멘스' '루트로닉' '매커스' '서진오토모티브' '아이티센' '안랩' '와이솔' '유아이디' '제이시스메디칼'
#  '인화정공' '진양제약' '파버나인' '파인테크닉스' '피엔티' '하이로닉' '에스피시스템스' '비올' '이베스트스팩5호'
#  '대덕전자' '이루다' '아이디피' '넥스틴' '하나머스트7호스팩' 'DB금융스팩9호' '하이제6호스팩' '라온테크' '에스앤디']
# ['갤럭시아에스엠' '금호에이치티' '녹십자홀딩스' '대유에이텍' '케이비아이동국실업' '동남합성' '동방' '삼성SDI'
#  '삼성화재해상보험' '선도전기' '오리온' '웅진' '윌비스' '제일파마홀딩스' '코스맥스' '코웨이' '남성' '넷마블'
#  '대유플러스' '현대두산인프라코어' '두올' '삼양사' '아이에이치큐' '이스타코' '인디에프' '지역난방공사' '코아스'
#  '한국금융지주' '화승인더스트리' '넥센타이어' '농심홀딩스' '동서' '명문제약' '모토닉' '시디즈' '신성이엔지'
#  '일진디스플' '티웨이홀딩스' '한라홀딩스' '효성 ITX' 'LX하우시스' 'NAVER' 'SK케미칼' '덕양산업' '롯데푸드'
#  '미래아이앤지' '아모레퍼시픽' '애경케미칼' '에스원' '우신시스템' '유안타증권' '코오롱글로벌' '쿠쿠홈시스' '키움증권'
#  '태영건설' '한화생명' '현대엘리베이터' 'SNT중공업' 'SK가스' '국보' '녹십자' '동원F&B' '서흥' '웅진씽크빅'
#  '한솔케미칼' '휴비스' 'F&F 홀딩스' 'GS리테일' 'LG' '엘에스일렉트릭' '금호타이어' '대원강업' '대원화성' '만도'
#  '조광피혁' '종근당홀딩스' '코오롱인더' '한국앤컴퍼니' '한온시스템' '핸즈코퍼레이션' 'KC코트렐' '다올투자증권'
#  'LG생활건강' '계양전기' '넥센' '대호에이엘' '두산' '세종공업' '신세계푸드' '에쓰씨엔지니어링' '에이리츠' '이연제약'
#  '일신석재' '일진다이아' '한국타이어앤테크놀로지' '한미사이언스' '한세예스24홀딩스' '한전기술' '현대홈쇼핑'
#  '화승코퍼레이션' '경동나비엔' 'DL' '대우부품' '서연이화' '에넥스' '에이프로젠제약' '우리종금' '이노션' '이마트'
#  '인팩' '쿠쿠홀딩스' 'KH 필룩스' '휠라홀딩스' 'EG' 'NHN한국사이버결제' '갤럭시아머니트리' '승일' '에디슨EV'
#  '아이즈비전' '액션스퀘어' '잉크테크' '조아제약' '켐트로스' '코웰패션' '판타지오' '푸른저축은행' '피에스엠씨'
#  '하나마이크론' '헝셩그룹' 'CMG제약' '나노' '넥스턴바이오' '뉴파워프라즈마' '대주전자재료' '동아엘텍' '디아이티'
#  '비츠로셀' '삼륭물산' '상아프론테크' '에스엘바이오닉스' '아가방컴퍼니' '에스퓨얼셀' 'HLB' '에이프로젠 H&G'
#  '와이즈버즈' '오리엔탈정공' '우리산업홀딩스' '윈팩' '제일바이오' '코데즈컴바인' '테고사이언스' '포스코엠텍'
#  '한국유니온제약' '경남제약' '넵튠' '대원산업' '동신건설' '디에스케이' '비씨월드제약' '삼진엘앤디' '아프리카TV'
#  '엠에스오토텍' '웹스' '웹케시' '코드네이처' '코나아이' '파나진' '휴젤' '자비스' '나무기술' '네이처셀' '지씨셀'
#  '대양전기공업' '바이온' '비디아이' '수산아이앤티' '씨앤지하이테크' '아이크래프트' '뉴지랩파마' '우수AMS' '이니텍'
#  '정원엔시스' '체리부로' '크리스탈신소재' '티케이케미칼' '피씨엘' 'CJ ENM' '가온미디어' '아이윈' '다믈멀티미디어'
#  '대원미디어' '더블유게임즈' '엔투텍' '삼보모터스' '삼천당제약' '서울옥션' '솔고바이오' '신신제약' '신화인터텍'
#  '폴라리스우노' '우리산업' '이수앱지스' '폴라리스오피스' '중앙디앤엠' '중앙백신' '카스' '피에이치에이' '푸드나무'
#  'GRT' '케이티알파' '대화제약' '라온시큐어' '메가엠디' '메디프론' '베스파' '솔브레인홀딩스' '아난티' '아시아경제'
#  '아주IB투자' '에스맥' 'HLB생명과학' '유니슨' '유니테크노' '유라테크' '소니드' '일지테크' '브이티지엠피'
#  '지티지웰니스' '예선테크' '케이엘넷' '코디엠' '디와이씨' 'NEW' '노랑풍선' '뉴트리' '다나와' '동일철강'
#  '모베이스전자' '폴라리스세원' '아바텍' '에코프로' '오가닉티코스메틱' '오성첨단소재' '우리기술투자' '웰크론한텍'
#  '유니온커뮤니티' '이노테라피' '인지디스플레' '장원테크' '크레버스' '지나인제약' '파워넷' '한국테크놀로지' '한빛소프트'
#  '비케이홀딩스' 'THE E&M' '넥스트아이' '데브시스터즈' '메가스터디' '씨아이에스' '씨케이에이치' '에스에너지'
#  '에스텍' '베노홀딩스' '아이윈플러스' '위즈코프' '이베스트투자증권' '콘텐트리중앙' '코미코' '키이스트' '토박스코리아'
#  '퓨쳐켐' '셀리드' '까스텔바작' '압타바이오' 'KBG' '올리패스' '아이티엠반도체' '캐리소프트' '두산퓨얼셀' '제테마'
#  '센트랄모텍' '리메드' '다보링크' '아이비김영' '제이앤티씨' '엔피디' '이엔드디' '와이팜' '한국파마'
#  '브랜드엑스코퍼레이션' '카카오게임즈' '이오플로우' '하이브' '피플바이오' '센코' '교촌에프앤비' '고바이오랩'
#  '에이플러스에셋' '제일전기공업' '씨이랩' '화승알앤에이' '네오이뮨텍' '에코프로에이치엔' '바이젠셀' '일진하이솔루스'
#  '에이비온' '툴젠' '프롬바이오']
# ['롯데케미칼' '보령' '엔씨소프트' '후성' '국동' '대한유화' '미원화학' '한국주강' '삼화전기' '일진머티리얼즈' '한샘'
#  'BNK금융지주' 'HDC랩스' '금호석유화학' '주연테크' '한화투자증권' '광전자' '디케이앤디' '비즈니스온' '원풍물산'
#  '코아스템' '코프라' '나노엔텍' '에이치앤비디자인' '이엔코퍼레이션' '서린바이오' '인크로스' '덱스터' '동일기연'
#  '바이오니아' '오텍' '제이티' '위메이드맥스' '큐브엔터' '파멥신' '네패스' '미스터블루' '셀트리온제약' '네오위즈'
#  '아이엘사이언스' '에이디테크놀로지' '케일럼' '인포마크' 'CBI' '국전약품' '디바이스이엔지' '민앤지' '버킷스튜디오'
#  '아이디스홀딩스' 'YBM넷' '펄어비스' '휴먼엔' '삼영이엔씨' '엠게임' '우정바이오' '지란지교시큐리티' '천보' '휴센텍'
#  '세운메디칼' '알서포트' '이녹스' '이씨에스' '마이크로디지탈' '미디어젠' '세림B&G' '소마젠' '엔젠바이오'
#  '에프앤가이드' '프레스티지바이오로직스' 'SK바이오사이언스' '자이언트스텝' '쿠콘' 'SK아이이테크놀로지' '삼영에스앤씨'
#  '카카오뱅크' '딥노이드' '한컴라이프케어' '아주스틸' '실리콘투' '아스플로' '차백신연구소']
# ['동양' '신풍제약' '영화금속' '유니온머티리얼' '조흥' '태양금속공업' '호전실업' 'BGF' 'KR모터스' 'OCI'
#  '깨끗한나라' '대양금속' '동성케미컬' '범양건영' '보해양조' '한전KPS' 'HJ중공업' '화승엔터프라이즈' 'CJ대한통운'
#  'KPX케미칼' '남광토건' '삼양통상' '삼영무역' '삼호개발' '유니온' '코스맥스비티아이' '퍼시스' '한섬' '현대그린푸드'
#  '남양유업' '대교' '롯데관광개발' '성문전자' '애경산업' '이건산업' '조선내화' '효성중공업' 'E1' 'SNT에너지'
#  '두산밥캣' '벽산' '비상교육' '신세계건설' '에이프로젠 MED' '인천도시가스' '케이씨티시' '평화산업' '한세엠케이'
#  'KC그린홀딩스' '광동제약' '동성제약' '두산에너빌리티' '롯데쇼핑' '태경비케이' '세하' '티비에이치글로벌' '한국내화'
#  '한솔로지스틱스' '현대건설' '현대리바트' '티케이지휴켐스' 'LS전선아시아' '가온전선' '대한화섬' '동아타이어'
#  '동양피스톤' '신풍제지' '영흥' '용평리조트' '케이티앤지' '아센디오' '한솔홈데코' '한전산업' 'CJ' '금화피에스시'
#  '대명소노시즌' '대한광통신' '대한약품' '부스타' '손오공' '클라우드에어' '아이텍' '원익큐브' '이노인스트루먼트'
#  '케이피티유' '스튜디오산타클로스' 'APS홀딩스' '케스피온' 'SM Life Design' '국영지앤엠' '대창솔루션'
#  '메타바이오메드' '세명전기' '씨씨에스' '씨큐브' '엘엠에스' '인포바인' '팬엔터테인먼트' 'JTC' '현대바이오랜드'
#  '다원시스' '대유' '리드코프' '린드먼아시아' '서산' '시노펙스' '원풍' '이건홀딩스' 'TKG애강' '리더스 기술투자'
#  '제이에스티나' '코리아에프티' 'TS인베스트먼트' '카이노스메드' '글로본' '동국산업' '라이온켐텍' '비보존 헬스케어'
#  '모헨즈' '코스나인' '상보' '상신전자' '새로닉스' '에스텍파마' '윈하이텍' '제로투세븐' '제룡전기' '제이씨현시스템'
#  '한창바이오텍' '하츠' '3S' 'CNH' 'SGA' '국보디자인' '나이스정보통신' '동아화성' '서한' '에스에이엠티'
#  '와이엠씨' '인선이엔티' '컬러레이' '케이사인' '플랜티넷' 'KD' '고려신용정보' '나이스디앤비' '율호' '비엘팜텍'
#  '누리플랜' '동국알앤에스' '디지캡' '삼보산업' '오하임아이엔티' '씨티케이' '조광ILI' '큐로컴' '티앤알바이오팹'
#  '팬스타엔터프라이즈' '원익피앤이' '덴티스' '한스바이오메드' 'KNN' 'SBI인베스트먼트' '코스맥스엔비티' '대성창투'
#  '드림시큐리티' '쇼박스' '오스템' '유성티엔에스' '한국알콜' '동구바이오제약' '디딤' '레이언스' '성창오토텍' '아진산업'
#  '알파홀딩스' '오상자이엘' '이글벳' '제일테크노스' '지엔씨에너지' '푸른기술' '프럼파스트' '아모그린텍' '코퍼스코리아'
#  '에이스토리' '한독크린텍' '코리아센터' '박셀바이오' 'DL이앤씨' '솔루엠' '큐라클' '한화플러스제2호스팩' '원티드랩']
# ['STX중공업' '상상인증권' '서원' '대림비앤코' '계룡건설산업' '미래산업' '쌍용씨앤이' 'STX' '풍산' '모비스'
#  '특수건설' '국일신동' '삼일' '삼표시멘트' '케이씨에스' '코메론' 'SDN' '스튜디오드래곤' '신진에스엠' 'KT서브마린'
#  '슈프리마에이치큐' '슈피겐코리아' '유진기업' '동원개발' '서희건설' '우원개발' '클래시스' '한화시스템' '플레이디'
#  '삼성스팩4호']
# ['GS건설' '한라' '풀무원' 'POSCO홀딩스' '바디텍메드' '코미팜' '티비씨' '대한과학' '서호전기' '동양파일'
#  '이엠넷' 'HB테크놀러지' 'THE MIDONG' '랩지노믹스' '슈프리마' '휴온스' 'KG이니시스' '링크제니시스'
#  '웨이버스' '케이씨씨글라스' '티와이홀딩스']
# ['무림페이퍼' '세이브존I&C' '한국주철관공업' '한미약품' '경동인베스트' '한국카본' '샘표식품' '동국제강' '동일제강'
#  '모나미' '우성' '한국프랜지공업' '제일기획' 'DSR' '화성밸브' '대동금속' '얼라인드' '보라티알' '우리손에프앤지'
#  '원익' '파루' '윙입푸드' '유비쿼스' '유비쿼스홀딩스' '팜스토리' '삼영엠텍' '솔루에타' '엘앤씨바이오' '엠에스씨'
#  '코리아에스이' '휴비츠' '대주산업' '이지홀딩스' '제이씨케미칼' '디젠스' '배럴' '성광벤드' '아세아텍' '오파스넷'
#  '제이브이엠' '슈프리마아이디' '신한제6호스팩' '일승' 'SK5호스팩' 'IBKS제12호스팩' '케이비제20호스팩'
#  '케이프이에스제4호' '이지바이오' '이지스밸류플러스리츠' '이지스레지던스리츠' '제이알글로벌리츠' '코람코에너지리츠'
#  '엔에이치스팩19호' 'SK리츠']
# ['KG케미칼' '선진' '진도' 'DRB동일' '동방아그로' '삼원강재' '엔케이' '코스모화학' '해태제과식품' 'MH에탄올'
#  'S-Oil' '대상홀딩스' '동원산업' '마니커' 'DSR제강' 'LF' '경인양행' '기업은행' '롯데정밀화학' '롯데지주'
#  '유니드' '한진중공업홀딩스' 'GS' '일진전기' 'DB' '성창기업지주' '세아홀딩스' '한솔제지' '광명전기' '대상'
#  '카프로' '크라운제과' '엑셈' '푸드웰' 'KMH' '골든센츄리' '신라에스지' '하이록코리아' '더블유에스아이' '메디포스트'
#  '쎄노텍' '쎄트렉아이' '이글루' 'SCI평가정보' 'WI' '가비아' '아시아종묘' '에이치케이' '대원' '아이디스'
#  '영풍정밀' '유니크' '정다운' '남화산업' '비츠로테크' '에이치엘사이언스' '우진비앤지' '인터엠' '오리콤' '하이즈항공'
#  '디케이락' '서울전자통신' '엘앤에프' '엘앤케이바이오' '그린플러스' '미래에셋맵스리츠' '삼성머스트스팩5호']
# Error in callback <function flush_figures at 0x0000019D88ADA940> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\IPython\core\formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\IPython\core\formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\backend_bases.py:2299, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
# -> 2299         bbox_inches = self.figure.get_tightbbox(
#    2300             renderer, bbox_extra_artists=bbox_extra_artists)
#    2301         if pad_inches is None:
#    2302             pad_inches = rcParams['savefig.pad_inches']
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\figure.py:1632, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1629     artists = bbox_extra_artists
#    1631 for a in artists:
# -> 1632     bbox = a.get_tightbbox(renderer)
#    1633     if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1634         bb.append(bbox)
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:4635, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4633         if bb_yaxis:
#    4634             bb.append(bb_yaxis)
# -> 4635 self._update_title_position(renderer)
#    4636 axbbox = self.get_window_extent(renderer)
#    4637 bb.append(axbbox)
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2996, in _AxesBase._update_title_position(self, renderer)
#    2994     _log.debug('top of Axes not in the figure, so title not moved')
#    2995     return
# -> 2996 if title.get_window_extent(renderer).ymin < top:
#    2997     _, y = self.transAxes.inverted().transform((0, top))
#    2998     title.set_position((x, y))
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\text.py:899, in Text.get_window_extent(self, renderer, dpi)
#     897 if self.get_text() == '':
#     898     with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 899         tx, ty = self._get_xy_display()
#     900         return Bbox.from_bounds(tx, ty, 0, 0)
#     902 if renderer is not None:
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\text.py:216, in Text._get_xy_display(self)
#     212 """
#     213 Get the (possibly unit converted) transformed x, y in display coords.
#     214 """
#     215 x, y = self.get_unitless_position()
# --> 216 return self.get_transform().transform((x, y))
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\transforms.py:1503, in Transform.transform(self, values)
#    1500 values = values.reshape((-1, self.input_dims))
#    1502 # Transform the values
# -> 1503 res = self.transform_affine(self.transform_non_affine(values))
#    1505 # Convert the result back to the shape of the input values.
#    1506 if ndim == 0:
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\transforms.py:2419, in CompositeGenericTransform.transform_affine(self, points)
#    2417 def transform_affine(self, points):
#    2418     # docstring inherited
# -> 2419     return self.get_affine().transform(points)
#
# File c:\Users\bigcare\Anaconda3\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
names[model.labels_ == 1]
# Out:
# array(['SK네트웍스', '대웅', '롯데하이마트', '미래에셋생명', '삼성출판사', '한국조선해양', 'SKC',
#        '동양생명', '세방전지', '종근당', '한독', '한일현대시멘트', 'YG PLUS', '비비안', '유진증권',
#        '유화증권', '종근당바이오', '텔코웨어', '한국자산신탁', '삼성물산', '세기상사', '셀트리온',
#        '씨에스윈드', '평화홀딩스', '포스코스틸리온', '한화', 'DB금융투자', 'KPX홀딩스', '디아이동일',
#        '부광약품', '신세계I&C', '카카오', '국도화학', '세아베스틸지주', '인바이오젠', '한올바이오파마',
#        '효성첨단소재', '다우기술', '동화약품', '일양약품', '한국쉘석유', '한익스프레스', 'KTcs',
#        '노루홀딩스', '대신증권', '동아에스티', '인스코비', '일성건설', '효성', '나스미디어', '디오',
#        '알테오젠', '위지트', '휴메딕스', '옵티시스', '에이비프로바이오', '정상제이엘에스', '포스코케미칼',
#        'SBS콘텐츠허브', '초록뱀컴퍼니', '디지털대성', '메디톡스', '쎌바이오텍', '아이오케이', '포스코 ICT',
#        '한국경제TV', '신원종합개발', '지니뮤직', '초록뱀미디어', '코엔텍', '경동제약', '아즈텍WB',
#        '앤디포스', '예스24', '이엠코리아', '파이오링크', '펩트론', '하이텍팜', '한국큐빅', '선익시스템',
#        '위지윅스튜디오', 'iMBC', '대정화금', '동양이엔피', '디알젬', '에스트래픽', '이크레더블', '멜파스',
#        '신일제약', '유비케어', '제룡산업', '차바이오텍', '코콤', '아이스크림에듀', '솔루스첨단소재',
#        '씨에스베어링', '라파스', '녹십자웰빙', '에스케이바이오팜', '미투젠', '비비씨', '비나텍',
#        '씨엔알리서치', '미코바이오메드', '위드텍', '하이딥', '석경에이티', '프레스티지바이오파마', '에이치피오',
#        '맥스트', '애드바이오텍', '래몽래인', '리파인', '지니너스'], dtype='<U14')
